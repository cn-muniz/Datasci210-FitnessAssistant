# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Read in json file
# df = pd.read_json('../../datasets/recipes_with_nutritional_info.json')
df = pd.read_json('../../datasets/recipes_with_servings_and_normalized_nutrients.json', lines=True)
df_corr = pd.read_json('../../datasets/recipes_with_servings_and_normalized_nutrients_corrected_quantities.json', lines=True)
df.head()
# Out:
#                                   fsa_lights_per100g          id  \
# 0  {'fat': 'orange', 'salt': 'green', 'saturates'...  0006ca31f4
# 1  {'fat': 'green', 'salt': 'red', 'saturates': '...  00073a6b36
# 2  {'fat': 'orange', 'salt': 'red', 'saturates': ...  0007f5f800
# 3  {'fat': 'green', 'salt': 'green', 'saturates':...  0008c6e39a
# 4  {'fat': 'orange', 'salt': 'red', 'saturates': ...  0009785a2e
#
#                                          ingredients  \
# 0  [{'text': 'cocoa, dry powder, unsweetened'}, {...
# 1  [{'text': 'cheese, pasteurized process, americ...
# 2  [{'text': 'cornmeal, degermed, unenriched, yel...
# 3  [{'text': 'sugars, powdered'}, {'text': 'wheat...
# 4  [{'text': 'rice, white, long-grain, regular, u...
#
#                                         instructions  \
# 0  [{'text': 'Measure out the cocoa powder into a...
# 1  [{'text': 'Put milk, onion salt and pepper sau...
# 2  [{'text': 'In a large skillet, stir the cornme...
# 3  [{'text': 'Move oven rack to lowest position.'...
# 4  [{'text': 'Add rice to a large pan of boiling ...
#
#                                  nutr_per_ingredient  \
# 0  [{'fat': 141.36, 'nrg': 2352.0, 'pro': 202.32,...
# 1  [{'fat': 54.0738363, 'nrg': 631.05987, 'pro': ...
# 2  [{'fat': 2.75, 'nrg': 581.0, 'pro': 11.16, 'sa...
# 3  [{'fat': 0.0, 'nrg': 700.5, 'pro': 0.0, 'sat':...
# 4  [{'fat': 0.44, 'nrg': 205.0, 'pro': 4.25, 'sat...
#
#                                  nutr_values_per100g partition  \
# 0  {'energy': 303.4353995519, 'fat': 5.0948469007...     train
# 1  {'energy': 57.1235315011, 'fat': 2.47764100560...     train
# 2  {'energy': 399.5182190719, 'fat': 18.337440469...     train
# 3  {'energy': 149.4259987004, 'fat': 0.3679178142...     train
# 4  {'energy': 57.3496659243, 'fat': 3.4322726627,...      test
#
#                                             quantity  \
# 0    [{'text': '12'}, {'text': '12'}, {'text': '1'}]
# 1  [{'text': '6'}, {'text': '13'}, {'text': '14'}...
# 2  [{'text': '1'}, {'text': '3/4'}, {'text': '3/4...
# 3  [{'text': '1 1/2'}, {'text': '3/4'}, {'text': ...
# 4  [{'text': '1'}, {'text': '3'}, {'text': '3'}, ...
#
#                                       title  \
# 0  Natural Peanut Butter Chocolate Bon Bons
# 1                         Easy Cheese Sauce
# 2      Cornmeal Crackers with Pumpkin Seeds
# 3          Chocolate-Orange Angel Food Cake
# 4         Rice With Lemon, Capers & Parsley
#
#                                                 unit  ... status found  error  \
# 0  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...  ...    200  True    NaN
# 1  [{'text': 'ounce'}, {'text': 'cup'}, {'text': ...  ...    200  True    NaN
# 2  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...  ...    200  True    NaN
# 3  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...  ...    200  True    NaN
# 4  [{'text': 'cup'}, {'text': 'cup'}, {'text': 't...  ...    200  True    NaN
#
#    n_servings  total_fat_per_serving  total_pro_per_serving  \
# 0        12.0              22.740000              22.620000
# 1         4.0              21.221703              34.425175
# 2         2.0              41.392187              16.085625
# 3         1.0               5.945000              57.592500
# 4         4.0               9.053906               2.161406
#
#    total_sod_per_serving  total_sat_per_serving total_sug_per_serving  \
# 0              35.333333               9.142667            282.130000
# 1            9195.832618              12.699995             42.204004
# 2            2352.156250              22.800094              6.873437
# 3            1201.500000               2.045500            442.950000
# 4            7085.093750               5.533250              0.194531
#
#    total_nrg_per_serving
# 0            1354.333333
# 1             489.279367
# 2             901.812500
# 3            2414.500000
# 4             151.281250
#
# [5 rows x 34 columns]

# %%
# title = "Dr. Oz. Energizing Breakfast: Canned Pumpkin Oatmeal"
title = "Zizania Chicken Salad"
# title = "Hawaiian Chicken Stir-Fry"
# title = "Easy Balsamic-Honey-Mustard Glazed Salmon"
# title = "Crunchy Broccoli Salad"
# Filter the dataframe for the specific recipe title
recipe_df = df[df['title'] == title]
recipe_df = recipe_df.reset_index(drop=True)
recipe_df
# Out:
#                                   fsa_lights_per100g          id  \
# 0  {'fat': 'green', 'salt': 'red', 'saturates': '...  38b55c38ac
#
#                                          ingredients  \
# 0  [{'text': 'wild rice, raw'}, {'text': 'chicken...
#
#                                         instructions  \
# 0  [{'text': 'To cook wild rice, rinse 1 cup wild...
#
#                                  nutr_per_ingredient  \
# 0  [{'fat': 5.19, 'nrg': 1713.0, 'pro': 70.71, 's...
#
#                                  nutr_values_per100g partition  \
# 0  {'energy': 62.7304514191, 'fat': 0.49785943850...     train
#
#                                             quantity                  title  \
# 0  [{'text': '3'}, {'text': '2'}, {'text': '2'}, ...  Zizania Chicken Salad
#
#                                                 unit  ... status found  error  \
# 0  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...  ...    200  True    NaN
#
#    n_servings  total_fat_per_serving  total_pro_per_serving  \
# 0         4.0               9.465667              50.586562
#
#    total_sod_per_serving  total_sat_per_serving total_sug_per_serving  \
# 0           14342.635417                 1.7011             102.82474
#
#    total_nrg_per_serving
# 0            1192.677083
#
# [1 rows x 34 columns]

# %%
recipe_df_corr = df_corr[df_corr['title'] == title]
recipe_df_corr = recipe_df_corr.reset_index(drop=True)
recipe_df_corr
# Out:
#                                   fsa_lights_per100g          id  \
# 0  {'fat': 'green', 'salt': 'red', 'saturates': '...  38b55c38ac
#
#                                          ingredients  \
# 0  [{'text': 'wild rice, raw'}, {'text': 'chicken...
#
#                                         instructions  \
# 0  [{'text': 'To cook wild rice, rinse 1 cup wild...
#
#                                  nutr_per_ingredient  \
# 0  [{'fat': 5.19, 'nrg': 1713.0, 'pro': 70.71, 's...
#
#                                  nutr_values_per100g partition  \
# 0  {'energy': 62.7304514191, 'fat': 0.49785943850...     train
#
#                                             quantity                  title  \
# 0  [{'text': '3'}, {'text': '2'}, {'text': '2'}, ...  Zizania Chicken Salad
#
#                                                 unit  ... error n_servings  \
# 0  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...  ...   NaN        4.0
#
#    total_fat_per_serving  total_pro_per_serving  total_sod_per_serving  \
# 0               5.751292              34.910938             630.697917
#
#    total_sat_per_serving  total_sug_per_serving  total_nrg_per_serving  \
# 0               0.877475               18.53724             610.552083
#
#                                   corrected_quantity  \
# 0  [{'text': '3'}, {'text': '2'}, {'text': '2'}, ...
#
#                                   adjusted_nutrients
# 0  [{'fat': 5.19, 'nrg': 1713.0, 'pro': 70.71, 's...
#
# [1 rows x 36 columns]

# %%
# join quantity, unit, and ingredients into a list of combined strings
# recipe_df['ingredients_combined'] = recipe_df.apply(lambda row: f"{row['quantity']} {row['unit']} {row['ingredients']}", axis=1)

# %%
print("Ingredients:")
for i in range(len(recipe_df['quantity'].values[0])):
    print(f"{recipe_df['quantity'].values[0][i]['text']} {recipe_df['unit'].values[0][i]['text']} {recipe_df['ingredients'].values[0][i]['text']}")
print("\nInstructions:")
for i in range(len(recipe_df['instructions'].values[0])):
    print(f"Step {i+1}: {recipe_df['instructions'].values[0][i]['text']}")
print("\nMacros:")
# Loop through macro nutrients and sum up per serving values
nutr_totals = {}
for nutr in recipe_df['nutr_per_ingredient'].values[0]:
    for k, v in nutr.items():
        # print(k,v)
        nutr_totals[k] = nutr_totals.get(k, 0) + v
n_servings = recipe_df['n_servings'].values[0]
# Print out macro nutrient values
for key, val in nutr_totals.items():
    print(f"{key}: {val/n_servings}")

# macro_key_vals = {
#     "total_fat_per_serving": "Fat (g)",
#     "total_pro_per_serving": "Protein (g)",
#     "total_sug_per_serving": "Carbs (g)",
#     "total_nrg_per_serving": "Calories"}
# for key, val in macro_key_vals.items():
#     print(f"{val}: {recipe_df[key].values[0]}")
# Out:
# Ingredients:
# 3 cup wild rice, raw
# 2 cup chicken, broiler or fryers, breast, skinless, boneless, meat only, raw
# 2 cup grapes, red or green (european type, such as thompson seedless), raw
# 14 cup celery, raw
# 14 cup onions, spring or scallions (includes tops and bulb), raw
# 2 tablespoon nuts, walnuts, english
# 2 tablespoon parsley, fresh
# 12 teaspoon salt, table
# 14 teaspoon spices, pepper, black
# 14 cup orange juice, raw
# 2 tablespoon vinegar, red wine
# 2 teaspoon sugars, granulated
# 1 teaspoon orange juice, raw
# 1 teaspoon spices, thyme, dried
# 12 teaspoon spices, rosemary, dried
# 12 teaspoon salt, table
#
# Instructions:
# Step 1: To cook wild rice, rinse 1 cup wild rice.
# Step 2: Bring wild rice and 4 cups water to a boil over high heat.
# Step 3: Stir.
# Step 4: Reduce heat, cover and simmer about 50 minutes or until kernels puff and open.
# Step 5: Makes about 3 cups cooked rice.
# Step 6: Prepare Orange-Herb Dressing.
# Step 7: Set aside.
# Step 8: Mix warm, cooked wild rice with 2 tablespoons Orange-Herb Dressing; mix well and cool.
# Step 9: Add remaining ingredients including remaining dressing.
# Step 10: Serve immediately or cover and refrigerate until serving.
#
# Macros:
# fat: 9.465666666675002
# nrg: 1192.677083333325
# pro: 50.58656250000001
# sat: 1.7011
# sod: 14342.635416666675
# sug: 102.82473958332498

# %%
print("Ingredients:")
for i in range(len(recipe_df_corr['corrected_quantity'].values[0])):
    print(f"{recipe_df_corr['corrected_quantity'].values[0][i]['text']} {recipe_df_corr['unit'].values[0][i]['text']} {recipe_df_corr['ingredients'].values[0][i]['text']}")
print("\nInstructions:")
for i in range(len(recipe_df_corr['instructions'].values[0])):
    print(f"Step {i+1}: {recipe_df_corr['instructions'].values[0][i]['text']}")
macro_key_vals = {
    "total_fat_per_serving": "Fat (g)",
    "total_pro_per_serving": "Protein (g)",
    "total_sug_per_serving": "Carbs (g)",
    "total_nrg_per_serving": "Calories"}

print("\nMacros:")
for key, val in macro_key_vals.items():
    print(f"{val}: {recipe_df_corr[key].values[0]}")
# Out:
# Ingredients:
# 3 cup wild rice, raw
# 2 cup chicken, broiler or fryers, breast, skinless, boneless, meat only, raw
# 2 cup grapes, red or green (european type, such as thompson seedless), raw
# 1/4 cup celery, raw
# 1/4 cup onions, spring or scallions (includes tops and bulb), raw
# 2 tablespoon nuts, walnuts, english
# 2 tablespoon parsley, fresh
# 1/2 teaspoon salt, table
# 1/4 teaspoon spices, pepper, black
# 1/4 cup orange juice, raw
# 2 tablespoon vinegar, red wine
# 2 teaspoon sugars, granulated
# 1 teaspoon orange juice, raw
# 1 teaspoon spices, thyme, dried
# 1/2 teaspoon spices, rosemary, dried
# 1/2 teaspoon salt, table
#
# Instructions:
# Step 1: To cook wild rice, rinse 1 cup wild rice.
# Step 2: Bring wild rice and 4 cups water to a boil over high heat.
# Step 3: Stir.
# Step 4: Reduce heat, cover and simmer about 50 minutes or until kernels puff and open.
# Step 5: Makes about 3 cups cooked rice.
# Step 6: Prepare Orange-Herb Dressing.
# Step 7: Set aside.
# Step 8: Mix warm, cooked wild rice with 2 tablespoons Orange-Herb Dressing; mix well and cool.
# Step 9: Add remaining ingredients including remaining dressing.
# Step 10: Serve immediately or cover and refrigerate until serving.
#
# Macros:
# Fat (g): 5.7512916667
# Protein (g): 34.9109375
# Carbs (g): 18.5372395833
# Calories: 610.5520833333

# %%
# save recipe_df to a json file
recipe_df.to_json('../../datasets/dr_oz_recipe.json', orient='records', lines=True)

# %%
import json

# %%
# print recipe_df as json string with newlines for nested json
a = recipe_df.to_json(orient='records', lines=True)
json_object = json.loads(a)
print(json.dumps(json_object, indent=2))
# Out:
# {
#   "fsa_lights_per100g": {
#     "fat": "green",
#     "salt": "green",
#     "saturates": "green",
#     "sugars": "green"
#   },
#   "id": "88eba8e160",
#   "ingredients": [
#     {
#       "text": "broccoli, raw"
#     },
#     {
#       "text": "fresh red onions, upc: 888670013229"
#     },
#     {
#       "text": "carrots, raw"
#     },
#     {
#       "text": "celery, raw"
#     },
#     {
#       "text": "seeds, sunflower seed kernels, dried"
#     },
#     {
#       "text": "raisins, seeded"
#     },
#     {
#       "text": "cranberries, dried, sweetened"
#     },
#     {
#       "text": "yogurt, greek, plain, nonfat"
#     },
#     {
#       "text": "yogurt, greek, plain, nonfat"
#     },
#     {
#       "text": "orange juice, raw"
#     },
#     {
#       "text": "salad dressing, mayonnaise, regular"
#     }
#   ],
#   "instructions": [
#     {
#       "text": "Chop broccoli into 1/2-3/4\" pieces."
#     },
#     {
#       "text": "Finely dice Celery & Red Onion."
#     },
#     {
#       "text": "Shred Carrot."
#     },
#     {
#       "text": "Combine all dry ingredients in bowl."
#     },
#     {
#       "text": "Whisk Yogurt/OJ/Mayo in small bowl pour over dry mixture, toss to coat."
#     }
#   ],
#   "nutr_per_ingredient": [
#     {
#       "fat": 1.36,
#       "nrg": 124.0,
#       "pro": 10.28,
#       "sat": 0.14,
#       "sod": 120.0,
#       "sug": 6.2
#     },
#     {
#       "fat": 0.0,
#       "nrg": 630.0,
#       "pro": 14.28,
#       "sat": 0.0,
#       "sod": 63.0,
#       "sug": 127.68
#     },
#     {
#       "fat": 4.34,
#       "nrg": 728.0,
#       "pro": 16.66,
#       "sat": 0.658,
#       "sod": 1232.0,
#       "sug": 84.98
#     },
#     {
#       "fat": 2.38,
#       "nrg": 224.0,
#       "pro": 9.8,
#       "sat": 0.588,
#       "sod": 1134.0,
#       "sug": 18.9
#     },
#     {
#       "fat": 2.95875,
#       "nrg": 33.625,
#       "pro": 1.195,
#       "sat": 0.256125,
#       "sod": 0.5,
#       "sug": 0.15125
#     },
#     {
#       "fat": 0.11125,
#       "nrg": 61.0,
#       "pro": 0.52,
#       "sat": 0.03675,
#       "sod": 5.75,
#       "sug": 0.0
#     },
#     {
#       "fat": 0.22,
#       "nrg": 61.5,
#       "pro": 0.035,
#       "sat": 0.0175,
#       "sod": 1.0,
#       "sug": 14.51
#     },
#     {
#       "fat": 12.4215,
#       "nrg": 1879.15,
#       "pro": 324.5515,
#       "sat": 3.72645,
#       "sod": 1146.6,
#       "sug": 103.194
#     },
#     {
#       "fat": 13.377,
#       "nrg": 2023.7,
#       "pro": 349.517,
#       "sat": 4.0131,
#       "sod": 1234.8,
#       "sug": 111.132
#     },
#     {
#       "fat": 0.0625,
#       "nrg": 14.0,
#       "pro": 0.2175,
#       "sat": 0.0075,
#       "sod": 0.25,
#       "sug": 2.60375
#     },
#     {
#       "fat": 10.33,
#       "nrg": 94.0,
#       "pro": 0.13,
#       "sat": 1.615,
#       "sod": 88.0,
#       "sug": 0.08
#     }
#   ],
#   "nutr_values_per100g": {
#     "energy": 47.4538781166,
#     "fat": 0.3842948245,
#     "protein": 5.875692611,
#     "salt": 0.1015236937,
#     "saturates": 0.0893525261,
#     "sugars": 3.7930216727
#   },
#   "partition": "train",
#   "quantity": [
#     {
#       "text": "4"
#     },
#     {
#       "text": "14"
#     },
#     {
#       "text": "14"
#     },
#     {
#       "text": "14"
#     },
#     {
#       "text": "2"
#     },
#     {
#       "text": "2"
#     },
#     {
#       "text": "2"
#     },
#     {
#       "text": "13"
#     },
#     {
#       "text": "14"
#     },
#     {
#       "text": "2"
#     },
#     {
#       "text": "1"
#     }
#   ],
#   "title": "Crunchy Broccoli Salad",
#   "unit": [
#     {
#       "text": "cup"
#     },
#     {
#       "text": "cup"
#     },
#     {
#       "text": "cup"
#     },
#     {
#       "text": "cup"
#     },
#     {
#       "text": "tablespoon"
#     },
#     {
#       "text": "tablespoon"
#     },
#     {
#       "text": "tablespoon"
#     },
#     {
#       "text": "cup"
#     },
#     {
#       "text": "cup"
#     },
#     {
#       "text": "tablespoon"
#     },
#     {
#       "text": "tablespoon"
#     }
#   ],
#   "url": "http://www.food.com/recipe/crunchy-broccoli-salad-454293",
#   "weight_per_ingr": [
#     364.0,
#     2100.0,
#     1792.0,
#     1414.0,
#     5.75,
#     20.625,
#     20.0,
#     3185.0,
#     3430.0,
#     31.0,
#     13.8
#   ]
# }
