# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json

# %% [markdown]
# # Final Ingredients Corrections

# %% [markdown]
# Go through our final recipes dataset with tagged ingredients and make any last corrections.

# %%
recipes = []
with open('../../VectorDB/recipes-vdb/app/data/final_combined_standardized_ingredients_tag.jsonl', 'r') as f:
    for line in f:
        recipes.append(json.loads(line))
df = pd.DataFrame(recipes)
df.head()
# Out:
#            id                                           title  cuisines  \
# 0  99d4a0f689  Summertime Stuffed and Grilled Chicken Breasts  [global]
# 1  99df626ce3                             Baby Vegetable Soup  [global]
# 2  99f60eccec                               Mushroom Salad II  [global]
# 3  9a1f55a2f6                               Caramelized Bacon  [global]
# 4  9a459c2e73                          Honey Cranberry Butter  [global]
#
#       course            methods           diet_tags_llm  \
# 0       main            [grill]          [high-protein]
# 1       soup  [saute, stir-fry]  [low-fat, gluten-free]
# 2      salad                 []           [gluten-free]
# 3       side             [bake]                      []
# 4  breakfast                 []   [dairy-free, low-fat]
#
#                                           diet_flags  \
# 0  {'vegetarian': False, 'vegan': False, 'pescata...
# 1  {'vegetarian': True, 'vegan': True, 'pescatari...
# 2  {'vegetarian': True, 'vegan': False, 'pescatar...
# 3  {'vegetarian': False, 'vegan': False, 'pescata...
# 4  {'vegetarian': True, 'vegan': False, 'pescatar...
#
#                                      diet_violations  \
# 0  {'vegetarian': ['chicken, broiler or fryers, b...
# 1  {'vegetarian': [], 'vegan': [], 'pescatarian':...
# 2  {'vegetarian': [], 'vegan': ['cheese, parmesan...
# 3  {'vegetarian': ['bacon, meatless'], 'vegan': [...
# 4  {'vegetarian': [], 'vegan': ['butter, without ...
#
#                           flavors  \
# 0  [smoky, herby, savory, cheesy]
# 1                 [mild, vegetal]
# 2   [tangy, herby, savory, umami]
# 3         [sweet, caramel, smoky]
# 4   [sweet, honey, fruity, nutty]
#
#                                              summary  ...   source_id  \
# 0  Grilled chicken breasts stuffed with sun-dried...  ...  99d4a0f689
# 1  Simple, comforting soup made with a variety of...  ...  99df626ce3
# 2  Raw mushroom salad with celery, parsley, parme...  ...  99f60eccec
# 3  Crispy, sweet, and smoky meatless bacon made b...  ...  9a1f55a2f6
# 4  Whipped butter with dried cranberries, honey, ...  ...  9a459c2e73
#
#   atwater_error_pct  data_source  \
# 0          0.509102   golden_set
# 1          2.845544   golden_set
# 2          0.807808   golden_set
# 3          2.811980   golden_set
# 4          1.600447   golden_set
#
#                                    merge_ingredients  \
# 0  [{'o': 'feta cheese', 'n': 'feta cheese', 'q':...
# 1  [{'o': 'composite household vegetable shorteni...
# 2  [{'o': 'raw white mushrooms', 'n': 'mushroom',...
# 3  [{'o': 'brown sugars', 'n': 'brown sugar', 'q'...
# 4  [{'o': 'without salt butter', 'n': 'butter', '...
#
#    original_macros_per_serving normalized_atwater_error_pct error_improvement  \
# 0                          NaN                          NaN               NaN
# 1                          NaN                          NaN               NaN
# 2                          NaN                          NaN               NaN
# 3                          NaN                          NaN               NaN
# 4                          NaN                          NaN               NaN
#
#   neighbors_count avg_neighbor_similarity confidence
# 0             NaN                     NaN        NaN
# 1             NaN                     NaN        NaN
# 2             NaN                     NaN        NaN
# 3             NaN                     NaN        NaN
# 4             NaN                     NaN        NaN
#
# [5 rows x 37 columns]

# %%
# How many rows are there?
print("Dataset contains {} individual recipes (without de-duping)".format(len(df)))
# Out:
# Dataset contains 13437 individual recipes (without de-duping)

# %%
recipe_id = "epi_1451"
# show recipe with this id
df[df["id"] == recipe_id]
# Out:
#             id                    title    cuisines course  methods  \
# 5348  epi_1451  Manhattan Clam Chowder   [american]   soup  [saute]
#
#       diet_tags_llm                                         diet_flags  \
# 5348  [gluten-free]  {'vegetarian': False, 'vegan': False, 'pescata...
#
#                                         diet_violations  \
# 5348  {'vegetarian': ['2 bacon slices, cut into 1/2-...
#
#                                 flavors  \
# 5348  [briny, savory, oniony, tomatoey]
#
#                                                 summary  ... source_id  \
# 5348  Hearty, comforting New England-style clam chow...  ...  epi_1451
#
#      atwater_error_pct  data_source  \
# 5348               0.0   epicurious
#
#                                       merge_ingredients  \
# 5348  [{'o': 'bacon slices, cut into 1/2-inch square...
#
#       original_macros_per_serving normalized_atwater_error_pct  \
# 5348                          NaN                          NaN
#
#      error_improvement neighbors_count avg_neighbor_similarity confidence
# 5348               NaN             NaN                     NaN        NaN
#
# [1 rows x 37 columns]

# %%
# Deduplicate recipes based on 'id' field
# Find all recipes with duplicate ids
duplicate_ids = df[df.duplicated(subset=['id'], keep=False)]['id'].unique()
print("Found {} duplicate recipe ids".format(len(duplicate_ids)))
# Out:
# Found 0 duplicate recipe ids

# %%
# Loop through all units and find all unique units
# Remove any rows with quantity of 0 or None or where 
units = set()
ingredients = set()

recipes_cleaned = []
removed_id_list = []
for index, row in df.iterrows():

    if len(row["units"]):
        keep_recipe = True
        for unit,quantity,ingredient in zip(row["units"],row["quantities"],row["ingredients_raw"]):
            # print(unit,quantity,ingredient)
            unit = unit["text"].lower().strip()
            quantity = quantity["text"]
            ingredient = " ".join(ingredient.lower().strip().split(",")[::-1])

            if quantity != 0.0 and quantity != None and unit != "N/A" and unit != "" and unit != "None" and unit != None:
                # See if unit is already in set
                if unit not in units:
                    units.add(unit)
                    ingredients.add(f"{quantity} {unit} of {ingredient}")
            else:
                keep_recipe = False
        if keep_recipe:
            recipes_cleaned.append(row)
    else:
        keep_recipe = True
        for mi in row["merge_ingredients"]:
            unit = mi.get("u","")
            quantity = mi.get("q","")
            ingredient = mi.get("o","").lower().strip()

            if quantity != 0.0 and quantity != None and unit != "N/A" and unit != "" and unit != "None" and unit != None:
                if unit not in units:
                    units.add(unit)
                    ingredients.add(f"{quantity} {unit} of {ingredient}")
            else:
                keep_recipe = False
        if keep_recipe:
            recipes_cleaned.append(row)

# Convert recipes_cleaned to dataframe
recipes_cleaned = pd.DataFrame(recipes_cleaned)

print("After cleaning, dataset contains {} individual recipes".format(len(recipes_cleaned)))
# Out:
# After cleaning, dataset contains 11922 individual recipes

# %%
recipe_id = "epi_1451"
# show recipe with this id
recipes_cleaned[recipes_cleaned["id"] == recipe_id]
# Out:
#             id                    title    cuisines course  methods  \
# 5348  epi_1451  Manhattan Clam Chowder   [american]   soup  [saute]
#
#       diet_tags_llm                                         diet_flags  \
# 5348  [gluten-free]  {'vegetarian': False, 'vegan': False, 'pescata...
#
#                                         diet_violations  \
# 5348  {'vegetarian': ['2 bacon slices, cut into 1/2-...
#
#                                 flavors  \
# 5348  [briny, savory, oniony, tomatoey]
#
#                                                 summary  ... source_id  \
# 5348  Hearty, comforting New England-style clam chow...  ...  epi_1451
#
#      atwater_error_pct  data_source  \
# 5348               0.0   epicurious
#
#                                       merge_ingredients  \
# 5348  [{'o': 'bacon slices, cut into 1/2-inch square...
#
#       original_macros_per_serving normalized_atwater_error_pct  \
# 5348                          NaN                          NaN
#
#      error_improvement neighbors_count avg_neighbor_similarity confidence
# 5348               NaN             NaN                     NaN        NaN
#
# [1 rows x 37 columns]

# %%
recipes_cleaned.head()
# Out:
#            id                                           title  cuisines  \
# 0  99d4a0f689  Summertime Stuffed and Grilled Chicken Breasts  [global]
# 1  99df626ce3                             Baby Vegetable Soup  [global]
# 2  99f60eccec                               Mushroom Salad II  [global]
# 3  9a1f55a2f6                               Caramelized Bacon  [global]
# 4  9a459c2e73                          Honey Cranberry Butter  [global]
#
#       course            methods           diet_tags_llm  \
# 0       main            [grill]          [high-protein]
# 1       soup  [saute, stir-fry]  [low-fat, gluten-free]
# 2      salad                 []           [gluten-free]
# 3       side             [bake]                      []
# 4  breakfast                 []   [dairy-free, low-fat]
#
#                                           diet_flags  \
# 0  {'vegetarian': False, 'vegan': False, 'pescata...
# 1  {'vegetarian': True, 'vegan': True, 'pescatari...
# 2  {'vegetarian': True, 'vegan': False, 'pescatar...
# 3  {'vegetarian': False, 'vegan': False, 'pescata...
# 4  {'vegetarian': True, 'vegan': False, 'pescatar...
#
#                                      diet_violations  \
# 0  {'vegetarian': ['chicken, broiler or fryers, b...
# 1  {'vegetarian': [], 'vegan': [], 'pescatarian':...
# 2  {'vegetarian': [], 'vegan': ['cheese, parmesan...
# 3  {'vegetarian': ['bacon, meatless'], 'vegan': [...
# 4  {'vegetarian': [], 'vegan': ['butter, without ...
#
#                           flavors  \
# 0  [smoky, herby, savory, cheesy]
# 1                 [mild, vegetal]
# 2   [tangy, herby, savory, umami]
# 3         [sweet, caramel, smoky]
# 4   [sweet, honey, fruity, nutty]
#
#                                              summary  ...   source_id  \
# 0  Grilled chicken breasts stuffed with sun-dried...  ...  99d4a0f689
# 1  Simple, comforting soup made with a variety of...  ...  99df626ce3
# 2  Raw mushroom salad with celery, parsley, parme...  ...  99f60eccec
# 3  Crispy, sweet, and smoky meatless bacon made b...  ...  9a1f55a2f6
# 4  Whipped butter with dried cranberries, honey, ...  ...  9a459c2e73
#
#   atwater_error_pct  data_source  \
# 0          0.509102   golden_set
# 1          2.845544   golden_set
# 2          0.807808   golden_set
# 3          2.811980   golden_set
# 4          1.600447   golden_set
#
#                                    merge_ingredients  \
# 0  [{'o': 'feta cheese', 'n': 'feta cheese', 'q':...
# 1  [{'o': 'composite household vegetable shorteni...
# 2  [{'o': 'raw white mushrooms', 'n': 'mushroom',...
# 3  [{'o': 'brown sugars', 'n': 'brown sugar', 'q'...
# 4  [{'o': 'without salt butter', 'n': 'butter', '...
#
#    original_macros_per_serving normalized_atwater_error_pct error_improvement  \
# 0                          NaN                          NaN               NaN
# 1                          NaN                          NaN               NaN
# 2                          NaN                          NaN               NaN
# 3                          NaN                          NaN               NaN
# 4                          NaN                          NaN               NaN
#
#   neighbors_count avg_neighbor_similarity confidence
# 0             NaN                     NaN        NaN
# 1             NaN                     NaN        NaN
# 2             NaN                     NaN        NaN
# 3             NaN                     NaN        NaN
# 4             NaN                     NaN        NaN
#
# [5 rows x 37 columns]

# %%
units
# Out:
# {'5-ounce 1/2-inch-thick',
#  'Belgian endives',
#  'Red Delicious',
#  'Tbsp',
#  'Tbsp.',
#  'accompaniment',
#  'bag',
#  'bags',
#  'baguette',
#  'ball',
#  'balls',
#  'basket',
#  'baskets',
#  'batch',
#  'bean',
#  'bell pepper',
#  'berries',
#  'black pepper',
#  'block',
#  'bottle',
#  'bottled',
#  'bottles',
#  'box',
#  'boxes',
#  'branch',
#  'branches',
#  'breast',
#  'bulb',
#  'bulbs',
#  'bunch',
#  'bunches',
#  'bundle',
#  'butter',
#  'cabbage',
#  'can',
#  'canned',
#  'canola oil',
#  'cans',
#  'carrot',
#  'carrots',
#  'chile',
#  'chiles',
#  'chili',
#  'chops',
#  'chunk',
#  'clove',
#  'cloves',
#  'cluster',
#  'coarse',
#  'container',
#  'containers',
#  'count',
#  'cracker',
#  'crown roast',
#  'crust',
#  'cube',
#  'cubes',
#  'cucumber',
#  'cup',
#  'cups',
#  'dash',
#  'dashes',
#  'diameter',
#  'dish',
#  'disk',
#  'dozen',
#  'dried',
#  'dried chorizos',
#  'drop',
#  'drops',
#  'each',
#  'ear',
#  'ears',
#  'envelope',
#  'envelopes',
#  'equipment',
#  'filet',
#  'filets',
#  'fillet',
#  'fillets',
#  'firm-ripe',
#  'fl oz',
#  'fl. oz',
#  'flat',
#  'flour',
#  'fluid ounce',
#  'g',
#  'gallon',
#  'gallons',
#  'gm',
#  'gram',
#  'grams',
#  'grating',
#  'green onion',
#  'grind',
#  'grinds',
#  'halves',
#  'handful',
#  'handfuls',
#  'head',
#  'heads',
#  'heart',
#  'hearts',
#  'inch',
#  'inch-long',
#  'inch-thick',
#  'jalapeño',
#  'jar',
#  'jars',
#  'juice',
#  'kg',
#  'knob',
#  'kosher salt',
#  'large',
#  'lb',
#  'lbs',
#  'leaf',
#  'leaves',
#  'leg',
#  'lemon',
#  'length',
#  'lengths',
#  'lime',
#  'link',
#  'links',
#  'liter',
#  'liters',
#  'litre',
#  'litres',
#  'loaf',
#  'loaves',
#  'log',
#  'logs',
#  'loin',
#  'mango',
#  'mayonnaise',
#  'medium',
#  'medium-size',
#  'ml',
#  'noodles',
#  'nuts',
#  'oil',
#  'olive oil',
#  'olives',
#  'onion',
#  'onions',
#  'ounce',
#  'ounces',
#  'oz',
#  'package',
#  'packages',
#  'packets',
#  'pair',
#  'pan',
#  'pans',
#  'paper',
#  'patties',
#  'patty',
#  'peel',
#  'peppercorns',
#  'peppers',
#  'piece',
#  'pieces',
#  'pinch',
#  'pinches',
#  'pineapple',
#  'pint',
#  'pints',
#  'plum',
#  'plus 1 tablespoon',
#  'pod',
#  'pods',
#  'potato',
#  'pound',
#  'pounds',
#  'pt',
#  'qt',
#  'qt plus 3 tablespoons',
#  'quart',
#  'quarter cup',
#  'quarts',
#  'rack',
#  'racks',
#  'recipe',
#  'red bell pepper',
#  'red onion',
#  'rib',
#  'ribs',
#  'rind',
#  'roast',
#  'rolls',
#  'round',
#  'rounds',
#  'sauce',
#  'sausage',
#  'scallion',
#  'scallions',
#  'scant cup',
#  'scoop',
#  'scoops',
#  'serving',
#  'shallot',
#  'sheet',
#  'sheets',
#  'shot glass',
#  'skeins',
#  'skewer',
#  'slab',
#  'slice',
#  'slicer',
#  'slices',
#  'small',
#  'small onion',
#  'sour cream',
#  'soy sauce',
#  'spears',
#  'splash',
#  'spray',
#  'sprig',
#  'sprigs',
#  'square',
#  'squares',
#  'squeeze',
#  'stalk',
#  'stalks',
#  'steak',
#  'steaks',
#  'stems',
#  'stick',
#  'sticks',
#  'strip',
#  'strips',
#  'sugar',
#  'syrup',
#  'tablespoon',
#  'tablespoon plus 1 teaspoon',
#  'tablespoons',
#  'tablespoons plus 1 cup',
#  'tail',
#  'tails',
#  'taste',
#  'tbsp',
#  'tea bag',
#  'tea bags',
#  'teaspoon',
#  'teaspoon plus 2 tablespoons',
#  'teaspoons',
#  'teaspoons and cup',
#  'teaspoons plus 2 tablespoons',
#  'threads',
#  'to taste',
#  'tomatoes',
#  'tortillas',
#  'total',
#  'tsp',
#  'tube',
#  'tubes',
#  'turns',
#  'wedge',
#  'wedges',
#  'wheel',
#  'whole',
#  'wineglass'}

# %% [markdown]
# The unit "dozen" confused the LLM for some ingredients so the quantity was multiplied by 12. Let's convert all "dozen" units to "count" and check the quantities. If the quantity is a multiple of 12, then leave as is, if not multiply by 12 to convert to "count".

# %%
# Loop through recipes_cleaned and find all ingredients where the unit or "u" is "dozen"
dozen_ingredients = []
for index, row in recipes_cleaned.iterrows():
    if len(row["units"]):
        units = []
        quantities = []
        ingredients_raw = []
        merge_ingredients = []
        unit_change_flag = False
        for unit,quantity,ingredient,mi in zip(row["units"],row["quantities"],row["ingredients_raw"], row["merge_ingredients"]):
            unit = unit["text"].lower().strip()
            quantity = quantity["text"]
            ingredient = " ".join(ingredient.lower().strip().split(",")[::-1])
            if unit == "dozen":
                unit_change_flag = True
                # Change unit to "count" and multiply quantity by 12 if not already multiple of 12
                if quantity < 12 and quantity % 12:
                    quantity *= 12
                unit = "count"
                mi["u"] = "count"
                mi["q"] = quantity
                dozen_ingredients.append((row["id"],ingredient,unit,quantity,mi))
            units.append(unit)
            quantities.append(quantity)
            ingredients_raw.append(ingredient)
            merge_ingredients.append(mi)
        if unit_change_flag:
            row["units"] = units
            row["quantities"] = quantities
            row["ingredients_raw"] = ingredients_raw
            row["merge_ingredients"] = merge_ingredients
    else:
        merge_ingredients = []
        unit_change_flag = False
        for mi, ingredient_raw in zip(row["merge_ingredients"],row["ingredients_raw"]):
            # print(mi)
            unit = mi.get("u","")
            if unit == None:
                unit = ""
            else:
                unit = unit.lower().strip()
            quantity = mi.get("q","")
            ingredient = mi.get("o","").lower().strip()
            if unit == "dozen":
                unit_change_flag = True
                # Change unit to "count" and multiply quantity by 12 if not already multiple of 12
                if quantity < 12 and quantity % 12:
                    quantity *= 12
                unit = "count"
                mi["u"] = "count"
                mi["q"] = quantity
                dozen_ingredients.append((row["id"],ingredient_raw,unit,quantity,mi))
            merge_ingredients.append(mi)
        if unit_change_flag:
            row["merge_ingredients"] = merge_ingredients

# %%
len(dozen_ingredients)
# Out:
# 20

# %%
# Deduplicate recipes based on 'id' field
# Find all recipes with duplicate ids
duplicate_ids = df[df.duplicated(subset=['id'], keep=False)]['id'].unique()
print("Found {} duplicate recipe ids".format(len(duplicate_ids)))
# Out:
# Found 0 duplicate recipe ids

# %%
dozen_ingredients
# Out:
# [('epi_1451',
#   '1 1/2 dozen small hard-shelled clams (1 1/2 to 2 inches in diameter; 2 pounds total), scrubbed well',
#   'count',
#   18.0,
#   {'o': 'small hard-shelled clams',
#    'n': 'clam',
#    'q': 18.0,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_3393',
#   '3 dozen small hard-shelled clams (2 to 2 1/2 inches in diameter; 3 1/2 lb total), scrubbed well',
#   'count',
#   36,
#   {'o': '3 dozen small hard-shelled clams (2 to 2 1/2 inches in diameter; 3 1/2 lb total), scrubbed well',
#    'n': 'clam',
#    'q': 36,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_4794',
#   '1 1/2 dozen small hard-shelled clams, shucked, reserving 1/2 cup liquor, and chopped',
#   'count',
#   18,
#   {'o': '1 1/2 dozen small hard-shelled clams, shucked, reserving 1/2 cup liquor, and chopped',
#    'n': 'clam',
#    'q': 18,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_4804',
#   '3 dozen mussels, scrubbed, debearded',
#   'count',
#   36,
#   {'o': 'mussels',
#    'n': 'mussel',
#    'q': 36,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'mussel'}),
#  ('epi_5256',
#   '2 dozen whole chicken wings',
#   'count',
#   24,
#   {'o': '2 dozen whole chicken wings',
#    'n': 'chicken wing',
#    'q': 24,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'chicken wing'}),
#  ('epi_6815',
#   '1 dozen small potatoes, scrubbed',
#   'count',
#   12,
#   {'o': '1 dozen small potatoes, scrubbed',
#    'n': 'small potato',
#    'q': 12,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Vegetables',
#    'm': 'small potato'}),
#  ('epi_9135',
#   '3 dozen littleneck clams, scrubbed',
#   'count',
#   36,
#   {'o': 'littleneck clams, scrubbed',
#    'n': 'clam',
#    'q': 36,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_9824',
#   '1 dozen clams, scrubbed',
#   'count',
#   12,
#   {'o': 'clams, scrubbed',
#    'n': 'clam',
#    'q': 12,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_9824',
#   '1 dozen mussels, scrubbed, debearded',
#   'count',
#   12,
#   {'o': 'mussels, scrubbed, debearded',
#    'n': 'mussel',
#    'q': 12,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'mussel'}),
#  ('epi_10188',
#   '1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed',
#   'count',
#   18,
#   {'o': '1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed',
#    'n': 'littleneck clam',
#    'q': 18,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'littleneck clam'}),
#  ('epi_10188',
#   '1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed',
#   'count',
#   18,
#   {'o': '1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed',
#    'n': 'mussel',
#    'q': 18,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'mussel'}),
#  ('epi_10282',
#   '2 dozen littleneck clams, scrubbed',
#   'count',
#   24,
#   {'o': 'littleneck clams, scrubbed',
#    'n': 'clam',
#    'q': 24,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_11618',
#   '4 dozen mussels (preferably cultivated)',
#   'count',
#   48,
#   {'o': '4 dozen mussels (preferably cultivated)',
#    'n': 'mussel',
#    'q': 48,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'mussel'}),
#  ('epi_11806',
#   '2 dozen oysters, shucked, reserving their liquid',
#   'count',
#   24,
#   {'o': '2 dozen oysters, shucked, reserving their liquid',
#    'n': 'oyster',
#    'q': 24,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'oyster'}),
#  ('epi_12457',
#   '6 Thai bird chilies or 1 serrano chili, cut into thin rings',
#   'count',
#   12,
#   {'o': 'saw-leaf herb',
#    'n': 'saw-leaf herb',
#    'q': 12,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Herbs and Spices',
#    'm': 'saw-leaf herb'}),
#  ('epi_13447',
#   '3 1/2 dozen small clams, scrubbed',
#   'count',
#   42.0,
#   {'o': 'small clams, scrubbed',
#    'n': 'clam',
#    'q': 42.0,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Seafood',
#    'm': 'clam'}),
#  ('epi_15928',
#   '6 dozen small hard-shelled clams such as littlenecks (less than 2 inches in diameter)',
#   'count',
#   72,
#   {'o': '6 dozen small hard-shelled clams such as littlenecks (less than 2 inches in diameter)',
#    'n': 'clam',
#    'q': 72,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Seafood',
#    'm': 'clam'}),
#  ('epi_16360',
#   '4 dozen littleneck or other small hard-shell clams',
#   'count',
#   48,
#   {'o': 'littleneck or other small hard-shell clams',
#    'n': 'clam',
#    'q': 48,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'clam'}),
#  ('epi_17136',
#   '4 dozen mussels, scrubbed, debearded',
#   'count',
#   48,
#   {'o': 'mussels, scrubbed, debearded',
#    'n': 'mussel',
#    'q': 48,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Meat and Fish',
#    'm': 'mussel'}),
#  ('epi_6411',
#   '2 dozen purchased frozen pierogies (such as potato-and-onion or cheese)',
#   'count',
#   24.0,
#   {'o': '2 dozen purchased frozen pierogies (such as potato-and-onion or cheese)',
#    'n': 'pierogy',
#    'q': 24.0,
#    'u': 'count',
#    'f': 'count',
#    'c': 'Frozen Foods',
#    'm': 'pierogy'})]

# %%
for i in range(len(dozen_ingredients)):
    print(f"Recipe ID: {dozen_ingredients[i][0]}")
    print(f"Ingredient Raw: {dozen_ingredients[i][1]}")
    print(f"New Unit: {dozen_ingredients[i][2]}")
    print(f"New Quantity: {dozen_ingredients[i][3]}")
    print(f"Merge Ingredient Entry: {dozen_ingredients[i][4]}")
    print("-----")
    r = recipes_cleaned[recipes_cleaned["id"] == dozen_ingredients[i][0]]
    print("Ingredients Raw:")
    for ingredient in r["ingredients_raw"].values[0]:
        print(ingredient)
    print("Units:")
    for unit in r["units"].values[0]:
        print(unit)
    print("Quantities:")
    for quantity in r["quantities"].values[0]:
        print(quantity)
    print("Merge Ingredients:")
    for mi in r["merge_ingredients"].values[0]:
        print(mi)
    print("==============\n")
# recipe_id = dozen_ingredients[2][0]
# # show recipe with this id
# r = recipes_cleaned[recipes_cleaned["id"] == recipe_id]
# r
# Out:
# Recipe ID: epi_1451
# Ingredient Raw: 1 1/2 dozen small hard-shelled clams (1 1/2 to 2 inches in diameter; 2 pounds total), scrubbed well
# New Unit: count
# New Quantity: 18.0
# Merge Ingredient Entry: {'o': 'small hard-shelled clams', 'n': 'clam', 'q': 18.0, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# 2 bacon slices, cut into 1/2-inch squares
# 1/3 cup chopped onion
# 3 tablespoons diced (1/3 inch) green bell pepper
# 3 tablespoons diced (1/3 inch) celery
# 2/3 cup diced (1/3 inch) peeled boiling potato (1 small)
# 1 (8-oz) bottle clam juice
# 1 cup canned diced tomatoes (8 oz), including juice
# 1 1/2 dozen small hard-shelled clams (1 1/2 to 2 inches in diameter; 2 pounds total), scrubbed well
# 2 tablespoons chopped fresh flat-leaf parsley
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'bacon slices, cut into 1/2-inch squares', 'n': 'bacon', 'q': 2, 'u': 'slices', 'f': 'count', 'c': 'Meat and Fish', 'm': 'bacon'}
# {'o': 'chopped onion', 'n': 'onion', 'q': 0.33, 'u': 'cup', 'f': 'volume', 'c': 'Vegetables', 'm': 'onion'}
# {'o': 'diced green bell pepper', 'n': 'green bell pepper', 'q': 0.25, 'u': 'tablespoons', 'f': 'volume', 'c': 'Vegetables', 'm': 'green bell pepper'}
# {'o': 'diced celery', 'n': 'celery', 'q': 0.25, 'u': 'tablespoons', 'f': 'volume', 'c': 'Vegetables', 'm': 'celery'}
# {'o': 'diced peeled boiling potato', 'n': 'potato', 'q': 0.67, 'u': 'cup', 'f': 'volume', 'c': 'Vegetables', 'm': 'potato'}
# {'o': 'clam juice', 'n': 'clam juice', 'q': 1, 'u': 'bottle', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'clam juice'}
# {'o': 'canned diced tomatoes', 'n': 'diced tomato', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Cans and Jars', 'm': 'diced tomato'}
# {'o': 'small hard-shelled clams', 'n': 'clam', 'q': 18.0, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': 'chopped fresh flat-leaf parsley', 'n': 'parsley', 'q': 0.33, 'u': 'tablespoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'parsley'}
# ==============
#
# Recipe ID: epi_3393
# Ingredient Raw: 3 dozen small hard-shelled clams (2 to 2 1/2 inches in diameter; 3 1/2 lb total), scrubbed well
# New Unit: count
# New Quantity: 36
# Merge Ingredient Entry: {'o': '3 dozen small hard-shelled clams (2 to 2 1/2 inches in diameter; 3 1/2 lb total), scrubbed well', 'n': 'clam', 'q': 36, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# 1/2 lb sliced bacon, chopped
# 1 medium onion, chopped
# 2 garlic cloves, finely chopped
# 1/2 teaspoon dried hot red pepper flakes
# 2 1/2 lb tomatoes, chopped
# 3 dozen small hard-shelled clams (2 to 2 1/2 inches in diameter; 3 1/2 lb total), scrubbed well
# 5 oz baby spinach (4 cups packed)
# Accompaniment: crusty bread
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '1/2 lb sliced bacon, chopped', 'n': 'sliced bacon', 'q': 0.5, 'u': 'lb', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'sliced bacon'}
# {'o': '1 medium onion, chopped', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '2 garlic cloves, finely chopped', 'n': 'garlic', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': '1/2 teaspoon dried hot red pepper flakes', 'n': 'hot red pepper flakes', 'q': 0.5, 'u': 'teaspoon', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'hot red pepper flakes'}
# {'o': '2 1/2 lb tomatoes, chopped', 'n': 'tomato', 'q': 2.5, 'u': 'lb', 'f': 'mass', 'c': 'Vegetables', 'm': 'tomato'}
# {'o': '3 dozen small hard-shelled clams (2 to 2 1/2 inches in diameter; 3 1/2 lb total), scrubbed well', 'n': 'clam', 'q': 36, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': '5 oz baby spinach (4 cups packed)', 'n': 'spinach', 'q': 5, 'u': 'oz', 'f': 'mass', 'c': 'Vegetables', 'm': 'spinach'}
# {'o': 'Accompaniment: crusty bread', 'n': 'crusty bread', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Bread and Baked Goods', 'm': 'crusty bread'}
# ==============
#
# Recipe ID: epi_4794
# Ingredient Raw: 1 1/2 dozen small hard-shelled clams, shucked, reserving 1/2 cup liquor, and chopped
# New Unit: count
# New Quantity: 18
# Merge Ingredient Entry: {'o': '1 1/2 dozen small hard-shelled clams, shucked, reserving 1/2 cup liquor, and chopped', 'n': 'clam', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# 2 slices bacon, chopped
# 1 small onion, chopped fine
# 1 celery rib, chopped
# 1 garlic clove, minced
# 1 1/2 dozen small hard-shelled clams, shucked, reserving 1/2 cup liquor, and chopped
# 1/3 cup dry white wine
# 1 cup water
# 2 teaspoons tomato paste
# 1 small boiling potato
# 2 medium vine-ripened tomatoes, seeded and chopped
# 2 tablespoons finely chopped fresh parsley leaves
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '2 slices bacon, chopped', 'n': 'bacon', 'q': 2, 'u': 'slices', 'f': 'count', 'c': 'Meat and Fish', 'm': 'bacon'}
# {'o': '1 small onion, chopped fine', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '1 celery rib, chopped', 'n': 'celery', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'celery'}
# {'o': '1 garlic clove, minced', 'n': 'garlic', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': '1 1/2 dozen small hard-shelled clams, shucked, reserving 1/2 cup liquor, and chopped', 'n': 'clam', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': '1/3 cup dry white wine', 'n': 'white wine', 'q': 0.3333333333333333, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': '1 cup water', 'n': 'water', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'water'}
# {'o': '2 teaspoons tomato paste', 'n': 'tomato paste', 'q': 2, 'u': 'teaspoons', 'f': 'count', 'c': 'Sauces and Condiments', 'm': 'tomato paste'}
# {'o': '1 small boiling potato', 'n': 'potato', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'potato'}
# {'o': '2 medium vine-riped tomatoes, seeded and chopped', 'n': 'tomato', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'tomato'}
# {'o': '2 tablespoons finely chopped fresh parsley leaves', 'n': 'parsley', 'q': 2, 'u': 'tablespoons', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'parsley'}
# ==============
#
# Recipe ID: epi_4804
# Ingredient Raw: 3 dozen mussels, scrubbed, debearded
# New Unit: count
# New Quantity: 36
# Merge Ingredient Entry: {'o': 'mussels', 'n': 'mussel', 'q': 36, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# -----
# Ingredients Raw:
# 2 tablespoons oriental sesame oil
# 2 1/2 cups thinly sliced red onions
# 8 ounces hot links sausage, cut into 1/2-inch pieces
# 1/4 cup thinly sliced peeled lemongrass
# 1 tablespoon minced peeled fresh ginger
# 1 tablespoon minced garlic
# 2 cups fish stock or bottled clam juice
# 1 cup canned unsweetened coconut milk
# 3 tablespoons fresh lime juice
# 2 tablespoons rice vinegar
# 1 tablespoon soy sauce
# 1 1/2 teaspoons ground coriander
# 1/4 cup chopped fresh cilantro
# 3 dozen mussels, scrubbed, debearded
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'oriental sesame oil', 'n': 'sesame oil', 'q': 2, 'u': 'tablespoons', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'sesame oil'}
# {'o': 'red onions', 'n': 'red onion', 'q': 2.5, 'u': 'cups', 'f': 'volume', 'c': 'Vegetables', 'm': 'red onion'}
# {'o': 'hot links sausage', 'n': 'hot link sausage', 'q': 8, 'u': 'ounces', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'hot link sausage'}
# {'o': 'lemongrass', 'n': 'lemongrass', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'lemongrass'}
# {'o': 'ginger', 'n': 'ginger', 'q': 0.017, 'u': 'tablespoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'ginger'}
# {'o': 'garlic', 'n': 'garlic', 'q': 0.017, 'u': 'tablespoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'garlic'}
# {'o': 'fish stock', 'n': 'fish stock', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'fish stock'}
# {'o': 'coconut milk', 'n': 'coconut milk', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Cans and Jars', 'm': 'coconut milk'}
# {'o': 'lime juice', 'n': 'lime juice', 'q': 0.15, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'lime juice'}
# {'o': 'rice vinegar', 'n': 'rice vinegar', 'q': 0.04, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'rice vinegar'}
# {'o': 'soy sauce', 'n': 'soy sauce', 'q': 0.017, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'soy sauce'}
# {'o': 'coriander', 'n': 'coriander', 'q': 0.008, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'coriander'}
# {'o': 'cilantro', 'n': 'cilantro', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'cilantro'}
# {'o': 'mussels', 'n': 'mussel', 'q': 36, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# ==============
#
# Recipe ID: epi_5256
# Ingredient Raw: 2 dozen whole chicken wings
# New Unit: count
# New Quantity: 24
# Merge Ingredient Entry: {'o': '2 dozen whole chicken wings', 'n': 'chicken wing', 'q': 24, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'chicken wing'}
# -----
# Ingredients Raw:
# 2 dozen whole chicken wings
# Kosher salt and freshly ground pepper
# 3/4 cup Only Sauce , plus more for serving, optional
# 1/4 cup whiskey
# 1 tablespoon sugar
# 1/4 cup plus 2 tablespoons Dijon mustard
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '2 dozen whole chicken wings', 'n': 'chicken wing', 'q': 24, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'chicken wing'}
# {'o': 'Kosher salt and freshly ground pepper', 'n': 'pepper', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'pepper'}
# {'o': '3/4 cup Only Sauce , plus more for serving, optional', 'n': 'sauce', 'q': 0.75, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'sauce'}
# {'o': '1/4 cup whiskey', 'n': 'whiskey', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'whiskey'}
# {'o': '1 tablespoon sugar', 'n': 'sugar', 'q': 1, 'u': 'tablespoon', 'f': 'volume', 'c': 'Bread and Baked Goods', 'm': 'sugar'}
# {'o': '1/4 cup plus 2 tablespoons Dijon mustard', 'n': 'mustard', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'mustard'}
# ==============
#
# Recipe ID: epi_6815
# Ingredient Raw: 1 dozen small potatoes, scrubbed
# New Unit: count
# New Quantity: 12
# Merge Ingredient Entry: {'o': '1 dozen small potatoes, scrubbed', 'n': 'small potato', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'small potato'}
# -----
# Ingredients Raw:
# 1 dozen small potatoes, scrubbed
# 1/2 cup (125 ml) crème fraîche
# The leaves from 1 large bunch chervil
# Sea salt and freshly ground black pepper
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '1 dozen small potatoes, scrubbed', 'n': 'small potato', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'small potato'}
# {'o': '1/2 cup (125 ml) crème fraîche', 'n': 'crème fraîche', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Dairy', 'm': 'crème fraîche'}
# {'o': 'The leaves from 1 large bunch chervil', 'n': 'chervil', 'q': 1, 'u': 'bunch', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'chervil'}
# {'o': 'Sea salt and freshly ground black pepper', 'n': 'black pepper', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'black pepper'}
# ==============
#
# Recipe ID: epi_9135
# Ingredient Raw: 3 dozen littleneck clams, scrubbed
# New Unit: count
# New Quantity: 36
# Merge Ingredient Entry: {'o': 'littleneck clams, scrubbed', 'n': 'clam', 'q': 36, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# 1/4 cup olive oil
# 2 cups chopped onions
# 1 medium fennel bulb with fronds, finely chopped
# 2 1/2 tablespoons minced garlic
# 2 teaspoons fennel seeds
# 2 cups dry white wine
# 1 1/4 pounds plum tomatoes, chopped
# 2 tablespoons Pernod (anise-flavored liqueur)
# 3 dozen littleneck clams, scrubbed
# 2 teaspoons chopped fresh oregano or 3/4 teaspoon dried
# Lemon wedges
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'olive oil', 'n': 'olive oil', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': 'onions', 'n': 'onion', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Vegetables', 'm': 'onion'}
# {'o': 'fennel bulb with fronds, finely chopped', 'n': 'fennel', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'fennel'}
# {'o': 'garlic', 'n': 'garlic', 'q': 2.5, 'u': 'tablespoons', 'f': 'volume', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': 'fennel seeds', 'n': 'fennel seed', 'q': 2, 'u': 'teaspoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'fennel seed'}
# {'o': 'dry white wine', 'n': 'white wine', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': 'plum tomatoes, chopped', 'n': 'plum tomato', 'q': 1.25, 'u': 'pounds', 'f': 'mass', 'c': 'Vegetables', 'm': 'plum tomato'}
# {'o': 'Pernod (anise-flavored liqueur)', 'n': 'Pernod', 'q': 0.02, 'u': 'tablespoons', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'Pernod'}
# {'o': 'littleneck clams, scrubbed', 'n': 'clam', 'q': 36, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': 'oregano or dried', 'n': 'oregano', 'q': 0.02, 'u': 'teaspoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'oregano'}
# {'o': 'Lemon wedges', 'n': 'lemon', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Fruits', 'm': 'lemon'}
# ==============
#
# Recipe ID: epi_9824
# Ingredient Raw: 1 dozen clams, scrubbed
# New Unit: count
# New Quantity: 12
# Merge Ingredient Entry: {'o': 'clams, scrubbed', 'n': 'clam', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# 1 tablespoon olive oil
# 5 bacon slices, chopped
# 1 3 1/2-pound whole chicken, cut into 8 pieces
# 2 cups chopped onions (about 2 medium)
# 4 garlic cloves, minced
# 2 cups long-grain white rice
# 1 7-ounce jar roasted sliced pimientos with juice
# 1/2 teaspoon crushed saffron threads
# 2 cups bottled clam juice
# 1 1/2 cups chicken stock or canned low-salt chicken broth
# 1 pound large uncooked shrimp, peeled, deveined
# 1 pound cleaned squid, bodies cut into 1/2-inch rings
# 1 dozen clams, scrubbed
# 1 dozen mussels, scrubbed, debearded
# 1 cup frozen green peas, thawed
# Lemon wedges
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'olive oil', 'n': 'olive oil', 'q': 1, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': 'bacon slices, chopped', 'n': 'bacon', 'q': 5, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'bacon'}
# {'o': 'whole chicken, cut into 8 pieces', 'n': 'chicken', 'q': 1.75, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'chicken'}
# {'o': 'chopped onions', 'n': 'onion', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Vegetables', 'm': 'onion'}
# {'o': 'garlic cloves, minced', 'n': 'garlic', 'q': 4, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': 'long-grain white rice', 'n': 'rice', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Pasta, Rice, and Cereals', 'm': 'rice'}
# {'o': 'roasted sliced pimientos with juice', 'n': 'pimiento', 'q': 0.35, 'u': 'jar', 'f': 'count', 'c': 'Cans and Jars', 'm': 'pimiento'}
# {'o': 'crushed saffron threads', 'n': 'saffron', 'q': 0.5, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'saffron'}
# {'o': 'bottled clam juice', 'n': 'clam juice', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'clam juice'}
# {'o': 'chicken stock or canned low-salt chicken broth', 'n': 'chicken broth', 'q': 1.5, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'chicken broth'}
# {'o': 'large uncooked shrimp, peeled, deveined', 'n': 'shrimp', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'shrimp'}
# {'o': 'cleaned squid, bodies cut into 1/2-inch rings', 'n': 'squid', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'squid'}
# {'o': 'clams, scrubbed', 'n': 'clam', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': 'mussels, scrubbed, debearded', 'n': 'mussel', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# {'o': 'frozen green peas, thawed', 'n': 'green pea', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Frozen Foods', 'm': 'green pea'}
# {'o': 'Lemon wedges', 'n': 'lemon', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Fruits', 'm': 'lemon'}
# ==============
#
# Recipe ID: epi_9824
# Ingredient Raw: 1 dozen mussels, scrubbed, debearded
# New Unit: count
# New Quantity: 12
# Merge Ingredient Entry: {'o': 'mussels, scrubbed, debearded', 'n': 'mussel', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# -----
# Ingredients Raw:
# 1 tablespoon olive oil
# 5 bacon slices, chopped
# 1 3 1/2-pound whole chicken, cut into 8 pieces
# 2 cups chopped onions (about 2 medium)
# 4 garlic cloves, minced
# 2 cups long-grain white rice
# 1 7-ounce jar roasted sliced pimientos with juice
# 1/2 teaspoon crushed saffron threads
# 2 cups bottled clam juice
# 1 1/2 cups chicken stock or canned low-salt chicken broth
# 1 pound large uncooked shrimp, peeled, deveined
# 1 pound cleaned squid, bodies cut into 1/2-inch rings
# 1 dozen clams, scrubbed
# 1 dozen mussels, scrubbed, debearded
# 1 cup frozen green peas, thawed
# Lemon wedges
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'olive oil', 'n': 'olive oil', 'q': 1, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': 'bacon slices, chopped', 'n': 'bacon', 'q': 5, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'bacon'}
# {'o': 'whole chicken, cut into 8 pieces', 'n': 'chicken', 'q': 1.75, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'chicken'}
# {'o': 'chopped onions', 'n': 'onion', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Vegetables', 'm': 'onion'}
# {'o': 'garlic cloves, minced', 'n': 'garlic', 'q': 4, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': 'long-grain white rice', 'n': 'rice', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Pasta, Rice, and Cereals', 'm': 'rice'}
# {'o': 'roasted sliced pimientos with juice', 'n': 'pimiento', 'q': 0.35, 'u': 'jar', 'f': 'count', 'c': 'Cans and Jars', 'm': 'pimiento'}
# {'o': 'crushed saffron threads', 'n': 'saffron', 'q': 0.5, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'saffron'}
# {'o': 'bottled clam juice', 'n': 'clam juice', 'q': 2, 'u': 'cups', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'clam juice'}
# {'o': 'chicken stock or canned low-salt chicken broth', 'n': 'chicken broth', 'q': 1.5, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'chicken broth'}
# {'o': 'large uncooked shrimp, peeled, deveined', 'n': 'shrimp', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'shrimp'}
# {'o': 'cleaned squid, bodies cut into 1/2-inch rings', 'n': 'squid', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'squid'}
# {'o': 'clams, scrubbed', 'n': 'clam', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': 'mussels, scrubbed, debearded', 'n': 'mussel', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# {'o': 'frozen green peas, thawed', 'n': 'green pea', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Frozen Foods', 'm': 'green pea'}
# {'o': 'Lemon wedges', 'n': 'lemon', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Fruits', 'm': 'lemon'}
# ==============
#
# Recipe ID: epi_10188
# Ingredient Raw: 1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed
# New Unit: count
# New Quantity: 18
# Merge Ingredient Entry: {'o': '1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed', 'n': 'littleneck clam', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'littleneck clam'}
# -----
# Ingredients Raw:
# 1 lemon, halved
# 3 medium artichokes or 1 (10-ounce) box frozen artichoke hearts, thawed
# pound green beans, trimmed and cut into 3-inch pieces
# 1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed
# 1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed
# 1/2 cup dry white wine
# 1 (3- to 3 1/2-pound) chicken, cut into 12 pieces
# 4 tablespoons olive oil
# 1 large onion, chopped
# 2 garlic cloves, minced
# 2 tablespoons paprika (preferably Spanish)
# 2 cups medium-grain rice
# 1 (14 1/2-ounce) can diced tomatoes, drained
# 1 3/4 cups chicken broth
# 2 red bell peppers, cut into 1/4-inch-thick strips
# Special equipment: a 15 3/4- by 2 3/4-inch paella pan
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'lemon, halved', 'n': 'lemon', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Fruits', 'm': 'lemon'}
# {'o': 'artichokes or 1 (10-ounce) box frozen artichoke hearts, thawed', 'n': 'artichoke', 'q': 3, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'artichoke'}
# {'o': 'pound green beans, trimmed and cut into 3-inch pieces', 'n': 'green bean', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Vegetables', 'm': 'green bean'}
# {'o': '1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed', 'n': 'littleneck clam', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'littleneck clam'}
# {'o': '1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed', 'n': 'mussel', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# {'o': '1/2 cup dry white wine', 'n': 'white wine', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': '1 (3- to 3 1/2-pound) chicken, cut into 12 pieces', 'n': 'chicken', 'q': 3.25, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'chicken'}
# {'o': '4 tablespoons olive oil', 'n': 'olive oil', 'q': 4, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': '1 large onion, chopped', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '2 garlic cloves, minced', 'n': 'garlic', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': '2 tablespoons paprika (preferably Spanish)', 'n': 'paprika', 'q': 2, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'paprika'}
# {'o': '2 cups medium-grain rice', 'n': 'rice', 'q': 2, 'u': 'cup', 'f': 'volume', 'c': 'Pasta, Rice, and Cereals', 'm': 'rice'}
# {'o': '1 (14 1/2-ounce) can diced tomatoes, drained', 'n': 'diced tomato', 'q': 14.5, 'u': 'can', 'f': 'count', 'c': 'Cans and Jars', 'm': 'diced tomato'}
# {'o': '1 3/4 cups chicken broth', 'n': 'chicken broth', 'q': 1.75, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'chicken broth'}
# {'o': '2 red bell peppers, cut into 1/4-inch-thick strips', 'n': 'red bell pepper', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'red bell pepper'}
# ==============
#
# Recipe ID: epi_10188
# Ingredient Raw: 1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed
# New Unit: count
# New Quantity: 18
# Merge Ingredient Entry: {'o': '1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed', 'n': 'mussel', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# -----
# Ingredients Raw:
# 1 lemon, halved
# 3 medium artichokes or 1 (10-ounce) box frozen artichoke hearts, thawed
# pound green beans, trimmed and cut into 3-inch pieces
# 1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed
# 1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed
# 1/2 cup dry white wine
# 1 (3- to 3 1/2-pound) chicken, cut into 12 pieces
# 4 tablespoons olive oil
# 1 large onion, chopped
# 2 garlic cloves, minced
# 2 tablespoons paprika (preferably Spanish)
# 2 cups medium-grain rice
# 1 (14 1/2-ounce) can diced tomatoes, drained
# 1 3/4 cups chicken broth
# 2 red bell peppers, cut into 1/4-inch-thick strips
# Special equipment: a 15 3/4- by 2 3/4-inch paella pan
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'lemon, halved', 'n': 'lemon', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Fruits', 'm': 'lemon'}
# {'o': 'artichokes or 1 (10-ounce) box frozen artichoke hearts, thawed', 'n': 'artichoke', 'q': 3, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'artichoke'}
# {'o': 'pound green beans, trimmed and cut into 3-inch pieces', 'n': 'green bean', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Vegetables', 'm': 'green bean'}
# {'o': '1 1/2 dozen littleneck clams (1 1/2 to 2 inches in diameter), scrubbed', 'n': 'littleneck clam', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'littleneck clam'}
# {'o': '1 1/2 dozen mussels (preferably cultivated), scrubbed and beards removed', 'n': 'mussel', 'q': 18, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# {'o': '1/2 cup dry white wine', 'n': 'white wine', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': '1 (3- to 3 1/2-pound) chicken, cut into 12 pieces', 'n': 'chicken', 'q': 3.25, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'chicken'}
# {'o': '4 tablespoons olive oil', 'n': 'olive oil', 'q': 4, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': '1 large onion, chopped', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '2 garlic cloves, minced', 'n': 'garlic', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': '2 tablespoons paprika (preferably Spanish)', 'n': 'paprika', 'q': 2, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'paprika'}
# {'o': '2 cups medium-grain rice', 'n': 'rice', 'q': 2, 'u': 'cup', 'f': 'volume', 'c': 'Pasta, Rice, and Cereals', 'm': 'rice'}
# {'o': '1 (14 1/2-ounce) can diced tomatoes, drained', 'n': 'diced tomato', 'q': 14.5, 'u': 'can', 'f': 'count', 'c': 'Cans and Jars', 'm': 'diced tomato'}
# {'o': '1 3/4 cups chicken broth', 'n': 'chicken broth', 'q': 1.75, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'chicken broth'}
# {'o': '2 red bell peppers, cut into 1/4-inch-thick strips', 'n': 'red bell pepper', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'red bell pepper'}
# ==============
#
# Recipe ID: epi_10282
# Ingredient Raw: 2 dozen littleneck clams, scrubbed
# New Unit: count
# New Quantity: 24
# Merge Ingredient Entry: {'o': 'littleneck clams, scrubbed', 'n': 'clam', 'q': 24, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# Two 1 1/2-pound lobsters, bodies and tails split in half and gills removed (ask your fish monger to do this for you)
# 2 tablespoons butter, melted
# Salt
# Freshly ground pepper
# 1 pound jumbo shrimp, peeled and deveined (tails left intact)
# Extra virgin olive oil, for brushing
# 2 dozen littleneck clams, scrubbed
# Tarragon-Cilantro Salsa Verde , Sambal-Orange Vinaigrette and Chorizo-Lemon Butter , for serving
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'lobsters, bodies and tails split in half and gills removed', 'n': 'lobster', 'q': 2.5, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'lobster'}
# {'o': 'butter, melted', 'n': 'butter', 'q': 2, 'u': 'tablespoons', 'f': 'volume', 'c': 'Dairy', 'm': 'butter'}
# {'o': 'Salt', 'n': 'salt', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'salt'}
# {'o': 'Freshly ground pepper', 'n': 'pepper', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'pepper'}
# {'o': 'jumbo shrimp, peeled and deveined', 'n': 'shrimp', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'shrimp'}
# {'o': 'Extra virgin olive oil, for brushing', 'n': 'olive oil', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': 'littleneck clams, scrubbed', 'n': 'clam', 'q': 24, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': 'Tarragon-Cilantro Salsa Verde , Sambal-Orange Vinaigrette and Chorizo-Lemon Butter , for serving', 'n': 'salsa verde', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Sauces and Condiments', 'm': 'salsa verde'}
# ==============
#
# Recipe ID: epi_11618
# Ingredient Raw: 4 dozen mussels (preferably cultivated)
# New Unit: count
# New Quantity: 48
# Merge Ingredient Entry: {'o': '4 dozen mussels (preferably cultivated)', 'n': 'mussel', 'q': 48, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# -----
# Ingredients Raw:
# 4 dozen mussels (preferably cultivated)
# 2 red bell peppers
# 1 small onion
# 4 large garlic cloves
# 1/4 cup packed fresh cilantro sprigs
# 1 teaspoon dried oregano, crumbled
# 1/2 teaspoon cumin seeds
# 1 tablespoon olive oil
# 1/2 cup dry white wine
# 1/2 cup chicken broth
# 2 tablespoons fresh orange juice, or to taste
# Accompaniment: crusty bread
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '4 dozen mussels (preferably cultivated)', 'n': 'mussel', 'q': 48, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# {'o': '2 red bell peppers', 'n': 'red bell pepper', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'red bell pepper'}
# {'o': '1 small onion', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '4 large garlic cloves', 'n': 'garlic', 'q': 4, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': '1/4 cup packed fresh cilantro sprigs', 'n': 'cilantro', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'cilantro'}
# {'o': '1 teaspoon dried oregano, crumbled', 'n': 'oregano', 'q': 1, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'oregano'}
# {'o': '1/2 teaspoon cumin seeds', 'n': 'cumin seed', 'q': 0.5, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'cumin seed'}
# {'o': '1 tablespoon olive oil', 'n': 'olive oil', 'q': 1, 'u': 'tablespoon', 'f': 'volume', 'c': 'Drinks', 'm': 'olive oil'}
# {'o': '1/2 cup dry white wine', 'n': 'white wine', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': '1/2 cup chicken broth', 'n': 'chicken broth', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'chicken broth'}
# {'o': '2 tablespoons fresh orange juice, or to taste', 'n': 'orange juice', 'q': 2, 'u': 'tablespoon', 'f': 'volume', 'c': 'Drinks', 'm': 'orange juice'}
# {'o': 'Accompaniment: crusty bread', 'n': 'crusty bread', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Bread and Baked Goods', 'm': 'crusty bread'}
# ==============
#
# Recipe ID: epi_11806
# Ingredient Raw: 2 dozen oysters, shucked, reserving their liquid
# New Unit: count
# New Quantity: 24
# Merge Ingredient Entry: {'o': '2 dozen oysters, shucked, reserving their liquid', 'n': 'oyster', 'q': 24, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'oyster'}
# -----
# Ingredients Raw:
# shells from 1 1/2 pounds small shrimp
# 2 pounds frozen Alaskan King crab legs (about 4 legs), rinsed and broken into large pieces at joints of necessary
# 5 quarts water
# 1 onion, halved
# 1 carrot, halved
# 1 teaspoon whole black peppercorns
# 1 bay leaf
# 2 fresh parsley sprigs
# 1 1/2 teaspoons salt
# 1/3 cup vegetable oil
# 1/2 cup bread flour
# 2 large onions, chopped
# 1 green bell pepper, chopped
# 2 celery ribs, chopped
# 1 1/2 pounds small shrimp, shelled
# 1/2 pound lump crab meat, picked over
# 2 dozen oysters, shucked, reserving their liquid
# 1 cup thinly sliced scallion greens (about 1 bunch)
# Accompaniment: Cajun-style White Rice
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'shells from 1 1/2 pounds small shrimp', 'n': 'small shrimp shell', 'q': 1.5, 'u': 'pounds', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'small shrimp'}
# {'o': '2 pounds frozen Alaskan King crab legs (about 4 legs), rinsed and broken into large pieces at joints of necessary', 'n': 'Alaskan King crab leg', 'q': 2, 'u': 'pounds', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'Alaskan King crab leg'}
# {'o': '5 quarts water', 'n': 'water', 'q': 5, 'u': 'quarts', 'f': 'volume', 'c': 'Drinks', 'm': 'water'}
# {'o': '1 onion, halved', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '1 carrot, halved', 'n': 'carrot', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'carrot'}
# {'o': '1 teaspoon whole black peppercorns', 'n': 'black peppercorn', 'q': 1, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'black peppercorn'}
# {'o': '1 bay leaf', 'n': 'bay leaf', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'bay leaf'}
# {'o': '2 fresh parsley sprigs', 'n': 'parsley', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'parsley'}
# {'o': '1 1/2 teaspoons salt', 'n': 'salt', 'q': 1.5, 'u': 'teaspoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'salt'}
# {'o': '1/3 cup vegetable oil', 'n': 'vegetable oil', 'q': 0.3333333333333333, 'u': 'cup', 'f': 'volume', 'c': 'Snacks', 'm': 'vegetable oil'}
# {'o': '1/2 cup bread flour', 'n': 'bread flour', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Bread and Baked Goods', 'm': 'bread flour'}
# {'o': '2 large onions, chopped', 'n': 'onion', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '1 green bell pepper, chopped', 'n': 'green bell pepper', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'green bell pepper'}
# {'o': '2 celery ribs, chopped', 'n': 'celery', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'celery'}
# {'o': '1 1/2 pounds small shrimp, shelled', 'n': 'small shrimp', 'q': 1.5, 'u': 'pounds', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'small shrimp'}
# {'o': '1/2 pound lump crab meat, picked over', 'n': 'lump crab meat', 'q': 0.5, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'lump crab meat'}
# {'o': '2 dozen oysters, shucked, reserving their liquid', 'n': 'oyster', 'q': 24, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'oyster'}
# {'o': '1 cup thinly sliced scallion greens (about 1 bunch)', 'n': 'green onion', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Vegetables', 'm': 'green onion'}
# {'o': 'Accompaniment: Cajun-style White Rice', 'n': 'Cajun-style White Rice', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Bread and Baked Goods', 'm': 'Cajun-style White Rice'}
# ==============
#
# Recipe ID: epi_12457
# Ingredient Raw: 6 Thai bird chilies or 1 serrano chili, cut into thin rings
# New Unit: count
# New Quantity: 12
# Merge Ingredient Entry: {'o': 'saw-leaf herb', 'n': 'saw-leaf herb', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'saw-leaf herb'}
# -----
# Ingredients Raw:
# 5 pounds beef marrow or knuckle bones
# 2 pounds beef chuck, cut into 2 pieces
# 2 (3-inch) pieces ginger, cut in half lengthwise and lightly bruised with the flat side of a knife, lightly charred (see Note, below)
# 2 yellow onions, peeled and charred (see Note, below)
# 1/4 cup fish sauce
# 3 ounces rock sugar, or 3 tablespoons sugar
# 10 whole star anise, lightly toasted in a dry pan
# 6 whole cloves, lightly toasted in a dry pan
# 1 tablespoon sea salt
# 1 pound dried 1/16-inch-wide rice sticks, soaked, cooked and drained (see Tips, below)
# 1/3 pound beef sirloin, slightly frozen, then sliced paper-thin across the grain
# 1/2 yellow onion, sliced paper-thin
# 3 scallions, cut into thin rings
# 1/3 cup chopped cilantro
# 1 pound bean sprouts
# 10 sprigs Asian basil
# 1 dozen saw-leaf herb leaves (optional)
# 6 Thai bird chilies or 1 serrano chili, cut into thin rings
# 1 lime, cut into 6 thin wedges
# Freshly ground black pepper
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'beef marrow or knuckle bones', 'n': 'beef bone', 'q': 5, 'u': 'pounds', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'beef bone'}
# {'o': 'beef chuck', 'n': 'beef chuck', 'q': 2, 'u': 'pounds', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'beef chuck'}
# {'o': 'ginger', 'n': 'ginger', 'q': 2, 'u': 'pieces', 'f': 'count', 'c': 'Vegetables', 'm': 'ginger'}
# {'o': 'yellow onions', 'n': 'yellow onion', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'yellow onion'}
# {'o': 'fish sauce', 'n': 'fish sauce', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'fish sauce'}
# {'o': 'rock sugar', 'n': 'rock sugar', 'q': 3, 'u': 'ounces', 'f': 'mass', 'c': 'Bread and Baked Goods', 'm': 'rock sugar'}
# {'o': 'sugar', 'n': 'sugar', 'q': 3, 'u': 'tablespoons', 'f': 'volume', 'c': 'Bread and Baked Goods', 'm': 'sugar'}
# {'o': 'star anise', 'n': 'star anise', 'q': 10, 'u': 'whole', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'star anise'}
# {'o': 'cloves', 'n': 'cloves', 'q': 6, 'u': 'whole', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'cloves'}
# {'o': 'sea salt', 'n': 'sea salt', 'q': 1, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'sea salt'}
# {'o': 'rice sticks', 'n': 'rice stick', 'q': 0.167, 'u': 'pound', 'f': 'mass', 'c': 'Pasta, Rice, and Cereals', 'm': 'rice stick'}
# {'o': 'beef sirloin', 'n': 'beef sirloin', 'q': 0.333, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'beef sirloin'}
# {'o': 'yellow onion', 'n': 'yellow onion', 'q': 0.5, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'yellow onion'}
# {'o': 'scallions', 'n': 'green onion', 'q': 3, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'green onion'}
# {'o': 'cilantro', 'n': 'cilantro', 'q': 0.333, 'u': 'cup', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'cilantro'}
# {'o': 'bean sprouts', 'n': 'bean sprout', 'q': 1, 'u': 'pound', 'f': 'mass', 'c': 'Vegetables', 'm': 'bean sprout'}
# {'o': 'Asian basil', 'n': 'basil', 'q': 10, 'u': 'sprigs', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'basil'}
# {'o': 'saw-leaf herb', 'n': 'saw-leaf herb', 'q': 12, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'saw-leaf herb'}
# {'o': 'Thai bird chilies', 'n': 'Thai chili', 'q': 6, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'Thai chili'}
# {'o': 'serrano chili', 'n': 'serrano chili', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'serrano chili'}
# {'o': 'lime', 'n': 'lime', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Fruits', 'm': 'lime'}
# {'o': 'black pepper', 'n': 'black pepper', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'black pepper'}
# ==============
#
# Recipe ID: epi_13447
# Ingredient Raw: 3 1/2 dozen small clams, scrubbed
# New Unit: count
# New Quantity: 42.0
# Merge Ingredient Entry: {'o': 'small clams, scrubbed', 'n': 'clam', 'q': 42.0, 'u': 'count', 'f': 'count', 'c': 'Seafood', 'm': 'clam'}
# -----
# Ingredients Raw:
# 3 tablespoons olive oil
# 1 cup chopped shallots
# 2 tablespoons minced garlic
# 2 tablespoons chopped fresh thyme
# 3/4 cup dry white wine
# 1/4 teaspoon crushed saffron threads
# 3 1/2 dozen small clams, scrubbed
# 1/4 cup bottled clam juice
# 1 cup finely chopped red bell pepper
# 1 cup finely chopped yellow bell pepper
# 4 6-ounce halibut fillets
# 1 1/2 tablespoons chopped fresh cilantro
# 1 1/2 tablespoons chopped fresh basil
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'olive oil', 'n': 'olive oil', 'q': 3, 'u': 'tablespoons', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': 'chopped shallots', 'n': 'shallot', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Vegetables', 'm': 'shallot'}
# {'o': 'minced garlic', 'n': 'garlic', 'q': 2, 'u': 'tablespoons', 'f': 'volume', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': 'chopped fresh thyme', 'n': 'thyme', 'q': 2, 'u': 'tablespoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'thyme'}
# {'o': 'dry white wine', 'n': 'white wine', 'q': 0.75, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': 'crushed saffron threads', 'n': 'saffron', 'q': 0.25, 'u': 'teaspoon', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'saffron'}
# {'o': 'small clams, scrubbed', 'n': 'clam', 'q': 42.0, 'u': 'count', 'f': 'count', 'c': 'Seafood', 'm': 'clam'}
# {'o': 'bottled clam juice', 'n': 'clam juice', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'clam juice'}
# {'o': 'finely chopped red bell pepper', 'n': 'red bell pepper', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Vegetables', 'm': 'red bell pepper'}
# {'o': 'finely chopped yellow bell pepper', 'n': 'yellow bell pepper', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Vegetables', 'm': 'yellow bell pepper'}
# {'o': 'halibut fillets', 'n': 'halibut', 'q': 4, 'u': 'fillets', 'f': 'count', 'c': 'Meat and Fish', 'm': 'halibut'}
# {'o': 'chopped fresh cilantro', 'n': 'cilantro', 'q': 1.5, 'u': 'tablespoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'cilantro'}
# {'o': 'chopped fresh basil', 'n': 'basil', 'q': 1.5, 'u': 'tablespoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'basil'}
# ==============
#
# Recipe ID: epi_15928
# Ingredient Raw: 6 dozen small hard-shelled clams such as littlenecks (less than 2 inches in diameter)
# New Unit: count
# New Quantity: 72
# Merge Ingredient Entry: {'o': '6 dozen small hard-shelled clams such as littlenecks (less than 2 inches in diameter)', 'n': 'clam', 'q': 72, 'u': 'count', 'f': 'count', 'c': 'Seafood', 'm': 'clam'}
# -----
# Ingredients Raw:
# 6 dozen small hard-shelled clams such as littlenecks (less than 2 inches in diameter)
# cheesecloth for lining sieve
# 1/2 cup water
# 1/2 pound bacon (about 8 slices)
# 2 medium onions
# 4 garlic cloves
# 3 large Yukon Gold or other boiling potatoes (about 1 1/2 pounds)
# 2 large turnips (about 1 pound total)
# 2 medium fennel bulbs (sometimes called anise; about 1 pound total)
# a 28- to 32-ounce can whole tomatoes
# 1 cup dry white wine
# 2 tablespoons tomato paste (optional)
# 1 1/2 pounds skinless halibut fillets
# 1 cup packed fresh flat-leafed parsley or cilantro leaves
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '6 dozen small hard-shelled clams such as littlenecks (less than 2 inches in diameter)', 'n': 'clam', 'q': 72, 'u': 'count', 'f': 'count', 'c': 'Seafood', 'm': 'clam'}
# {'o': 'cheesecloth for lining sieve', 'n': 'cheesecloth', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Pantry', 'm': 'cheesecloth'}
# {'o': '1/2 cup water', 'n': 'water', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'water'}
# {'o': '1/2 pound bacon (about 8 slices)', 'n': 'bacon', 'q': 0.5, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'bacon'}
# {'o': '2 medium onions', 'n': 'onion', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '4 garlic cloves', 'n': 'garlic', 'q': 4, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'garlic'}
# {'o': '3 large Yukon Gold or other boiling potatoes (about 1 1/2 pounds)', 'n': 'potato', 'q': 3, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'potato'}
# {'o': '2 large turnips (about 1 pound total)', 'n': 'turnip', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'turnip'}
# {'o': '2 medium fennel bulbs (sometimes called anise; about 1 pound total)', 'n': 'fennel', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'fennel'}
# {'o': 'a 28- to 32-ounce can whole tomatoes', 'n': 'whole tomato', 'q': 30, 'u': 'can', 'f': 'count', 'c': 'Cans and Jars', 'm': 'whole tomato'}
# {'o': '1 cup dry white wine', 'n': 'white wine', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': '2 tablespoons tomato paste (optional)', 'n': 'tomato paste', 'q': 0.33, 'u': 'tablespoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'tomato paste'}
# {'o': '1 1/2 pounds skinless halibut fillets', 'n': 'halibut', 'q': 1.5, 'u': 'pound', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'halibut'}
# {'o': '1 cup packed fresh flat-leafed parsley or cilantro leaves', 'n': 'parsley', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'parsley'}
# ==============
#
# Recipe ID: epi_16360
# Ingredient Raw: 4 dozen littleneck or other small hard-shell clams
# New Unit: count
# New Quantity: 48
# Merge Ingredient Entry: {'o': 'littleneck or other small hard-shell clams', 'n': 'clam', 'q': 48, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# -----
# Ingredients Raw:
# 3 tablespoons olive oil
# 8 ounces lingui‧a, chorizo, or kielbasa sausage, sliced
# 1 large onion, chopped
# 2 14 1/2-ounce cans diced tomatoes with green pepper and garlic or Italian-recipe tomatoes
# 4 dozen littleneck or other small hard-shell clams
# 1 cup white wine
# 1/2 teaspoon (or more) hot pepper sauce
# 1/4 cup chopped fresh cilantro, divided
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'olive oil', 'n': 'olive oil', 'q': 3, 'u': 'tablespoons', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'olive oil'}
# {'o': 'lingui‧a, chorizo, or kielbasa sausage, sliced', 'n': 'lingui‧a sausage', 'q': 8, 'u': 'ounces', 'f': 'mass', 'c': 'Meat and Fish', 'm': 'lingui‧a sausage'}
# {'o': 'onion, chopped', 'n': 'onion', 'q': 1, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'onion'}
# {'o': 'diced tomatoes with green pepper and garlic or Italian-recipe tomatoes', 'n': 'diced tomato', 'q': 2.5, 'u': 'cans', 'f': 'count', 'c': 'Cans and Jars', 'm': 'diced tomato'}
# {'o': 'littleneck or other small hard-shell clams', 'n': 'clam', 'q': 48, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'clam'}
# {'o': 'white wine', 'n': 'white wine', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': 'hot pepper sauce', 'n': 'hot pepper sauce', 'q': 0.5, 'u': 'teaspoon', 'f': 'volume', 'c': 'Sauces and Condiments', 'm': 'hot pepper sauce'}
# {'o': 'fresh cilantro, divided', 'n': 'cilantro', 'q': 0.25, 'u': 'cup', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'cilantro'}
# ==============
#
# Recipe ID: epi_17136
# Ingredient Raw: 4 dozen mussels, scrubbed, debearded
# New Unit: count
# New Quantity: 48
# Merge Ingredient Entry: {'o': 'mussels, scrubbed, debearded', 'n': 'mussel', 'q': 48, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# -----
# Ingredients Raw:
# 2 tablespoons (1/4 stick) butter
# 2 large leeks (white and pale green parts only), thinly sliced
# 4 dozen mussels, scrubbed, debearded
# 1 cup dry white wine
# 8 fresh parsley sprigs
# 10 saffron threads, crushed
# 1/2 cup whipping cream
# 2 tablespoons minced fresh parsley
# Units:
# Quantities:
# Merge Ingredients:
# {'o': 'butter', 'n': 'butter', 'q': 2, 'u': 'tablespoons', 'f': 'volume', 'c': 'Dairy', 'm': 'butter'}
# {'o': 'leeks, thinly sliced', 'n': 'leek', 'q': 2, 'u': 'count', 'f': 'count', 'c': 'Vegetables', 'm': 'leek'}
# {'o': 'mussels, scrubbed, debearded', 'n': 'mussel', 'q': 48, 'u': 'count', 'f': 'count', 'c': 'Meat and Fish', 'm': 'mussel'}
# {'o': 'dry white wine', 'n': 'white wine', 'q': 1, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'white wine'}
# {'o': 'parsley sprigs', 'n': 'parsley', 'q': 8, 'u': 'count', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'parsley'}
# {'o': 'saffron threads, crushed', 'n': 'saffron', 'q': 10, 'u': 'threads', 'f': 'count', 'c': 'Herbs and Spices', 'm': 'saffron'}
# {'o': 'whipping cream', 'n': 'whipping cream', 'q': 0.5, 'u': 'cup', 'f': 'volume', 'c': 'Dairy', 'm': 'whipping cream'}
# {'o': 'minced fresh parsley', 'n': 'parsley', 'q': 2, 'u': 'tablespoons', 'f': 'volume', 'c': 'Herbs and Spices', 'm': 'parsley'}
# ==============
#
# Recipe ID: epi_6411
# Ingredient Raw: 2 dozen purchased frozen pierogies (such as potato-and-onion or cheese)
# New Unit: count
# New Quantity: 24.0
# Merge Ingredient Entry: {'o': '2 dozen purchased frozen pierogies (such as potato-and-onion or cheese)', 'n': 'pierogy', 'q': 24.0, 'u': 'count', 'f': 'count', 'c': 'Frozen Foods', 'm': 'pierogy'}
# -----
# Ingredients Raw:
# 8 tablespoons (1 stick) butter
# 2 pounds onions, sliced
# 1 pound mushrooms, sliced
# 1 2-pound jar sauerkraut, well drained
# 1 tablespoon all purpose flour
# 2/3 cup (or more) water
# 2 dozen purchased frozen pierogies (such as potato-and-onion or cheese)
# Sour cream
# Units:
# Quantities:
# Merge Ingredients:
# {'o': '8 tablespoons (1 stick) butter', 'n': 'butter', 'q': 8.0, 'u': 'tablespoons', 'f': 'volume', 'c': 'Dairy', 'm': 'butter'}
# {'o': '2 pounds onions, sliced', 'n': 'onion', 'q': 2.0, 'u': 'pounds', 'f': 'mass', 'c': 'Vegetables', 'm': 'onion'}
# {'o': '1 pound mushrooms, sliced', 'n': 'mushroom', 'q': 1.0, 'u': 'pounds', 'f': 'mass', 'c': 'Vegetables', 'm': 'mushroom'}
# {'o': '1 2-pound jar sauerkraut, well drained', 'n': 'sauerkraut', 'q': 2.0, 'u': 'jar', 'f': 'count', 'c': 'Cans and Jars', 'm': 'sauerkraut'}
# {'o': '1 tablespoon all purpose flour', 'n': 'flour', 'q': 1.0, 'u': 'tablespoon', 'f': 'volume', 'c': 'Bread and Baked Goods', 'm': 'flour'}
# {'o': '2/3 cup (or more) water', 'n': 'water', 'q': 2.33, 'u': 'cup', 'f': 'volume', 'c': 'Drinks', 'm': 'water'}
# {'o': '2 dozen purchased frozen pierogies (such as potato-and-onion or cheese)', 'n': 'pierogy', 'q': 24.0, 'u': 'count', 'f': 'count', 'c': 'Frozen Foods', 'm': 'pierogy'}
# {'o': 'Sour cream', 'n': 'sour cream', 'q': 1.0, 'u': 'count', 'f': 'count', 'c': 'Dairy', 'm': 'sour cream'}
# ==============

# %%
# Save cleaned dataframe to jsonl
with open('../../VectorDB/recipes-vdb/app/data/final_combined_standardized_ingredients_tag_cleaned.jsonl', 'w') as f:
    for index, row in recipes_cleaned.iterrows():
        f.write(json.dumps(row.to_dict()) + '\n')

# %%
# load cleaned dataframe back in to verify
recipes_loaded = []
with open('../../VectorDB/recipes-vdb/app/data/final_combined_standardized_ingredients_tag_cleaned.jsonl', 'r') as f:
    for line in f:
        recipes_loaded.append(json.loads(line))
recipes_loaded = pd.DataFrame(recipes_loaded)
print("Loaded cleaned dataset contains {} individual recipes".format(len(recipes_loaded)))
# Out:
# Loaded cleaned dataset contains 11922 individual recipes
